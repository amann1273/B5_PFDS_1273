# %% [markdown]
# <a href="https://colab.research.google.com/github/amann1273/B5_PFDS_1273/blob/main/PFDS_lab3_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#q1
import numpy as np

a = np.random.randint(1, 10, (3, 3))
b = np.random.randint(1, 10, (3, 3))

add = np.add(a, b)
sub = np.subtract(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Addition:\n", add)
print("Subtraction:\n", sub)
# Out:
# Matrix A:
#  [[6 1 9]
#  [1 7 9]
#  [9 7 2]]
# Matrix B:
#  [[8 5 1]
#  [3 7 2]
#  [5 9 8]]
# Addition:
#  [[14  6 10]
#  [ 4 14 11]
#  [14 16 10]]
# Subtraction:
#  [[-2 -4  8]
#  [-2  0  7]
#  [ 4 -2 -6]]

# %%
#q2
import numpy as np
import matplotlib.pyplot as plt

a = np.random.randint(1, 5, (3, 2))
b = np.random.randint(1, 5, (2, 3))
c = np.dot(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Dot Product:\n", c)


plt.figure(figsize=(8, 3))

plt.subplot(1, 3, 1)
plt.imshow(a, cmap='viridis', interpolation='nearest')
plt.title("Matrix A")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(b, cmap='viridis', interpolation='nearest')
plt.title("Matrix B")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(c, cmap='viridis', interpolation='nearest')
plt.title("Dot Product")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Matrix A:
#  [[3 2]
#  [4 2]
#  [2 1]]
# Matrix B:
#  [[4 1 3]
#  [3 4 2]]
# Dot Product:
#  [[18 11 13]
#  [22 12 16]
#  [11  6  8]]

# %%
#ClassRoom_Files
import csv

with open("Classroom_file.csv", 'w', newline='') as fp:
    wr = csv.writer(fp)
    wr.writerow(["Name", "Marks"])
    for i in range(2):
        name = input("Enter name: ")
        marks = int(input("Enter marks: "))
        wr.writerow([name, marks])
